# %% [markdown]
# <a href="https://colab.research.google.com/github/PacktPublishing/Modern-Computer-Vision-with-PyTorch/blob/master/Chapter11/adversarial_attack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch_snippets
import torch
import torch.nn as nn

from torch_snippets import show, np
from torch_snippets.inspector import inspect

from torchvision.models import resnet50
model = resnet50(pretrained=True)
for param in model.parameters():
    param.requires_grad = False
model = model.eval()
import requests
from PIL import Image
url = 'https://lionsvalley.co.za/wp-content/uploads/2015/11/african-elephant-square.jpg'
original_image = Image.open(requests.get(url, stream=True).raw).convert('RGB')
original_image = np.array(original_image)
original_image = torch.Tensor(original_image)
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: torch_snippets in c:\users\hunter\anaconda3\lib\site-packages (0.547)
# Requirement already satisfied: fastcore in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (1.7.23)
# Requirement already satisfied: matplotlib in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (3.8.4)
# Requirement already satisfied: Pillow in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (10.4.0)
# Requirement already satisfied: dill in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (0.3.8)
# Requirement already satisfied: loguru in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (0.7.3)
# Requirement already satisfied: numpy in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (1.26.4)
# Requirement already satisfied: pandas in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (2.2.2)
# Requirement already satisfied: tqdm in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (4.66.4)
# Requirement already satisfied: rich in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (13.3.5)
# Requirement already satisfied: PyYAML in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (5.1)
# Requirement already satisfied: catalogue in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (2.0.10)
# Requirement already satisfied: confection in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (0.1.5)
# Requirement already satisfied: pydantic in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (2.9.2)
# Requirement already satisfied: typing in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (3.7.4.3)
# Requirement already satisfied: srsly in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (2.4.8)
# Requirement already satisfied: typing-extensions in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (4.11.0)
# Requirement already satisfied: wasabi in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (1.1.3)
# Requirement already satisfied: jsonlines in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (4.0.0)
# Requirement already satisfied: imgaug>=0.4.0 in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (0.4.0)
# Requirement already satisfied: xmltodict in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (0.14.2)
# Requirement already satisfied: fuzzywuzzy in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (0.18.0)
# Requirement already satisfied: nltk in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (3.9.1)
# Requirement already satisfied: python-Levenshtein in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (0.26.1)
# Requirement already satisfied: pre-commit in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (4.0.1)
# Requirement already satisfied: icecream in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (2.1.3)
# Requirement already satisfied: mergedeep in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (1.3.4)
# Requirement already satisfied: deepdiff in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (8.0.1)
# Requirement already satisfied: typer in c:\users\hunter\anaconda3\lib\site-packages (from torch_snippets) (0.12.5)
# Requirement already satisfied: six in c:\users\hunter\anaconda3\lib\site-packages (from imgaug>=0.4.0->torch_snippets) (1.16.0)
# Requirement already satisfied: scipy in c:\users\hunter\anaconda3\lib\site-packages (from imgaug>=0.4.0->torch_snippets) (1.13.1)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\users\hunter\anaconda3\lib\site-packages (from imgaug>=0.4.0->torch_snippets) (0.23.2)
# Requirement already satisfied: opencv-python in c:\users\hunter\anaconda3\lib\site-packages (from imgaug>=0.4.0->torch_snippets) (4.10.0.84)
# Requirement already satisfied: imageio in c:\users\hunter\anaconda3\lib\site-packages (from imgaug>=0.4.0->torch_snippets) (2.33.1)
# Requirement already satisfied: Shapely in c:\users\hunter\anaconda3\lib\site-packages (from imgaug>=0.4.0->torch_snippets) (2.0.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hunter\anaconda3\lib\site-packages (from pydantic->torch_snippets) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\hunter\anaconda3\lib\site-packages (from pydantic->torch_snippets) (2.23.4)
# Requirement already satisfied: orderly-set==5.2.2 in c:\users\hunter\anaconda3\lib\site-packages (from deepdiff->torch_snippets) (5.2.2)
# Requirement already satisfied: packaging in c:\users\hunter\anaconda3\lib\site-packages (from fastcore->torch_snippets) (23.2)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\hunter\anaconda3\lib\site-packages (from icecream->torch_snippets) (0.4.6)
# Requirement already satisfied: pygments>=2.2.0 in c:\users\hunter\anaconda3\lib\site-packages (from icecream->torch_snippets) (2.15.1)
# Requirement already satisfied: executing>=0.3.1 in c:\users\hunter\anaconda3\lib\site-packages (from icecream->torch_snippets) (0.8.3)
# Requirement already satisfied: asttokens>=2.0.1 in c:\users\hunter\anaconda3\lib\site-packages (from icecream->torch_snippets) (2.0.5)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hunter\anaconda3\lib\site-packages (from jsonlines->torch_snippets) (23.1.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\hunter\anaconda3\lib\site-packages (from loguru->torch_snippets) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hunter\anaconda3\lib\site-packages (from matplotlib->torch_snippets) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hunter\anaconda3\lib\site-packages (from matplotlib->torch_snippets) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hunter\anaconda3\lib\site-packages (from matplotlib->torch_snippets) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hunter\anaconda3\lib\site-packages (from matplotlib->torch_snippets) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hunter\anaconda3\lib\site-packages (from matplotlib->torch_snippets) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hunter\anaconda3\lib\site-packages (from matplotlib->torch_snippets) (2.9.0.post0)
# Requirement already satisfied: click in c:\users\hunter\anaconda3\lib\site-packages (from nltk->torch_snippets) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hunter\anaconda3\lib\site-packages (from nltk->torch_snippets) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hunter\anaconda3\lib\site-packages (from nltk->torch_snippets) (2023.10.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hunter\anaconda3\lib\site-packages (from pandas->torch_snippets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hunter\anaconda3\lib\site-packages (from pandas->torch_snippets) (2023.3)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\hunter\anaconda3\lib\site-packages (from pre-commit->torch_snippets) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\hunter\anaconda3\lib\site-packages (from pre-commit->torch_snippets) (2.6.3)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\hunter\anaconda3\lib\site-packages (from pre-commit->torch_snippets) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\hunter\anaconda3\lib\site-packages (from pre-commit->torch_snippets) (20.28.0)
# Requirement already satisfied: Levenshtein==0.26.1 in c:\users\hunter\anaconda3\lib\site-packages (from python-Levenshtein->torch_snippets) (0.26.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\hunter\anaconda3\lib\site-packages (from Levenshtein==0.26.1->python-Levenshtein->torch_snippets) (3.10.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\hunter\anaconda3\lib\site-packages (from rich->torch_snippets) (2.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hunter\anaconda3\lib\site-packages (from typer->torch_snippets) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hunter\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->torch_snippets) (0.1.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\hunter\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->torch_snippets) (3.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\hunter\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->torch_snippets) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\hunter\anaconda3\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->torch_snippets) (0.4)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\hunter\anaconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit->torch_snippets) (0.3.9)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\hunter\anaconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit->torch_snippets) (3.13.1)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\hunter\anaconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit->torch_snippets) (3.10.0)
# C:\Users\hunter\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\hunter\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
image_net_classes = 'https://gist.githubusercontent.com/yrevar/942d3a0ac09ec9e5eb3a/raw/238f720ff059c1f82f368259d1ca4ffa5dd8f9f5/imagenet1000_clsidx_to_labels.txt'
image_net_classes = requests.get(image_net_classes).text
image_net_ids = eval(image_net_classes)
image_net_classes = {i:j for j,i in image_net_ids.items()}

# %%
from torchvision import transforms as T
from torch.nn import functional as F
normalize = T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
denormalize = T.Normalize([-0.485/0.229, -0.456/0.224, -0.406/0.225], [1/0.229, 1/0.224, 1/0.225])
def image2tensor(input):
    x = normalize(input.clone().permute(2,0,1)/255.)[None]
    return x
def tensor2image(input):
    x = (denormalize(input[0].clone()).permute(1,2,0)*255.).type(torch.uint8)
    return x

# %%
def predict_on_image(input):
    model.eval()
    show(input)
    input = image2tensor(input)
    pred = model(input)
    pred = F.softmax(pred, dim=-1)[0]
    prob, clss = torch.max(pred, 0)
    clss = image_net_ids[clss.item()]
    print(f'PREDICTION: `{clss}` @ {prob.item()}')

# %%
from tqdm import trange
losses = []
def attack(image, model, target, epsilon=1e-6):
    input = image2tensor(image)
    input.requires_grad = True
    pred = model(input)
    loss = nn.CrossEntropyLoss()(pred, target)
    loss.backward()
    losses.append(loss.mean().item())
    output = input - epsilon * input.grad.sign()
    output = tensor2image(output)
    del input
    return output.detach()

# %%
modified_images = []
desired_targets = ['lemon', 'comic book', 'sax, saxophone']

# %%
for target in desired_targets:
    target = torch.tensor([image_net_classes[target]])
    image_to_attack = original_image.clone()
    for _ in trange(10):
        image_to_attack = attack(image_to_attack, model, target)
    modified_images.append(image_to_attack)
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  5.78it/s]
# 100%|██████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  5.98it/s]
# 100%|██████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  5.86it/s]

# %%
for image in [original_image, *modified_images]:
    predict_on_image(image)
    #inspect(image)
# Out:
# PREDICTION: `African elephant, Loxodonta africana` @ 0.5234397053718567
# PREDICTION: `lemon` @ 0.9999951124191284
# PREDICTION: `comic book` @ 0.9999853372573853
# PREDICTION: `sax, saxophone` @ 0.9999995231628418
